# %%
import pandas as pd

# Load the datasets
pre_assessment_data = pd.read_csv("../data/Med student pre assessment 2.8.23.csv")
foundational_post = pd.read_csv("../data/Foundational Post Assessment 2.8.23.csv")
intermediate_post = pd.read_csv("../data/intermediate post assessment 2.8.23.csv")
post_assessment_data = pd.read_csv("../data/Advanced post assessment 2.8.23.csv")
post_assessment_2022 = pd.read_csv("../data/IDD-MH Med Student Advanced Post Assessment_October 10, 2022_14.41.csv")

# %%
# # Remove rows where survey was not completed
# pre_assessment_data = pre_assessment_data[pre_assessment_data['Finished'] == 'TRUE']
# post_assessment_data = post_assessment_data[post_assessment_data['Finished'] == 'TRUE']

# # Convert data types if necessary, e.g., converting date strings to datetime objects
# pre_assessment_data['StartDate'] = pd.to_datetime(pre_training_data['StartDate'])
# post_assessment_data['StartDate'] = pd.to_datetime(post_training_data['StartDate'])

# # Handle or fill missing values as needed
# pre_assessment_data.fillna(method='ffill', inplace=True)

# %%
# # Basic descriptive statistics
# print(pre_training_data.describe())
# print(post_training_data.describe())

# # Visualization (using matplotlib or seaborn)
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Example: Plotting distribution of scores
# plt.hist(pre_training_data['SC0'], bins=20, alpha=0.5, label='Pre-training')
# plt.hist(post_training_data['SC0'], bins=20, alpha=0.5, label='Post-training')
# plt.legend()
# plt.show()

# %%
# post_assessment_data['SC0'].hist(bins=14)
# plt.xlabel('Score')
# plt.ylabel('Frequency')
# plt.title('Distribution of Post-Training Scores')
# plt.show()

# %%
# Identifying the relevant columns for analysis
score_column = 'SC0'
year_in_training_column = 'Q1'
response_id_column = 'ResponseId'

# Filtering out the non-numeric rows in score columns (like headers or metadata)
pre_assessment_data_filtered = pre_assessment_data[pd.to_numeric(pre_assessment_data[score_column], errors='coerce').notnull()]
post_assessment_data_filtered = post_assessment_data[pd.to_numeric(post_assessment_data[score_column], errors='coerce').notnull()]

# Converting score columns to numeric for analysis
pre_assessment_data_filtered[score_column] = pd.to_numeric(pre_assessment_data_filtered[score_column])
post_assessment_data_filtered[score_column] = pd.to_numeric(post_assessment_data_filtered[score_column])

# Merging the pre and post datasets based on ResponseId to analyze score improvements
merged_data = pre_assessment_data_filtered[[response_id_column, year_in_training_column, score_column]].merge(
    post_assessment_data_filtered[[response_id_column, score_column]],
    on=response_id_column,
    suffixes=('_pre', '_post')
)

# Computing score improvement
merged_data['score_improvement'] = merged_data[f'{score_column}_post'] - merged_data[f'{score_column}_pre']

# Displaying the first few rows of the merged dataset for an overview
merged_data_head = merged_data.head()
merged_data_head
# Out:
# /var/folders/dt/736qq0rj57q0_yg7067yzwyh0000gn/T/ipykernel_5741/4022701449.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_assessment_data_filtered[score_column] = pd.to_numeric(pre_assessment_data_filtered[score_column])
# /var/folders/dt/736qq0rj57q0_yg7067yzwyh0000gn/T/ipykernel_5741/4022701449.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   post_assessment_data_filtered[score_column] = pd.to_numeric(post_assessment_data_filtered[score_column])
# Empty DataFrame
# Columns: [ResponseId, Q1, SC0_pre, SC0_post, score_improvement]
# Index: []

# %%
# Inspecting the first few ResponseId values from both datasets to check for formatting inconsistencies
pre_response_ids_head = pre_assessment_data[response_id_column].head(10)
post_response_ids_head = post_assessment_data[response_id_column].head(10)

(pre_response_ids_head, post_response_ids_head)
# Out:
# (0                 Response ID
#  1    {"ImportId":"_recordId"}
#  2           R_djvqzijTB5L2Pjb
#  3           R_2zqcz6JEOzFKMf0
#  4           R_12SvBoipzeVQw2d
#  5           R_2SH7E5DZhOsRjZh
#  6           R_3PhIpFxHA8Ho4s8
#  7           R_210zyA6WedvYKdT
#  8           R_XHBBSTCim34VOtb
#  9           R_es03L5DQE4kCMO5
#  Name: ResponseId, dtype: object,
#  0                 Response ID
#  1    {"ImportId":"_recordId"}
#  2           R_31XbBuf7cpN9G8J
#  3           R_2D5lalLKtLsTWkZ
#  4           R_3D1hs06lyOhFtsk
#  5           R_32637n9t6RuswHP
#  6           R_3PLUU1EpPQfrJiy
#  7           R_21jIwrn4fEuch5D
#  8           R_24hK5CMUoA9UGkW
#  9           R_3PlncF0ASG7vtq9
#  Name: ResponseId, dtype: object)

# %%
# Filtering out header and metadata rows from both datasets
pre_assessment_data_cleaned = pre_assessment_data[2:]
post_assessment_data_cleaned = post_assessment_data[2:]

# Merging the cleaned pre and post datasets based on ResponseId
merged_data_cleaned = pre_assessment_data_cleaned[[response_id_column, year_in_training_column, score_column]].merge(
    post_assessment_data_cleaned[[response_id_column, score_column]],
    on=response_id_column,
    suffixes=('_pre', '_post')
)

# Converting score columns to numeric for analysis
merged_data_cleaned[score_column + '_pre'] = pd.to_numeric(merged_data_cleaned[score_column + '_pre'], errors='coerce')
merged_data_cleaned[score_column + '_post'] = pd.to_numeric(merged_data_cleaned[score_column + '_post'], errors='coerce')

# Dropping NaN values in score columns
merged_data_cleaned = merged_data_cleaned.dropna(subset=[score_column + '_pre', score_column + '_post'])

# Computing score improvement
merged_data_cleaned['score_improvement'] = merged_data_cleaned[score_column + '_post'] - merged_data_cleaned[score_column + '_pre']

# Displaying the first few rows of the merged dataset for an overview
merged_data_cleaned_head = merged_data_cleaned.head()
merged_data_cleaned_head
# Out:
# Empty DataFrame
# Columns: [ResponseId, Q1, SC0_pre, SC0_post, score_improvement]
# Index: []

# %%
# Checking for any overlapping ResponseId values between the two datasets
overlap_response_ids = set(pre_assessment_data_cleaned[response_id_column]).intersection(post_assessment_data_cleaned[response_id_column])

# Number of overlapping ResponseId values
num_overlap = len(overlap_response_ids)
num_overlap
# Out:
# 0

# %%
# Inspecting the column names of both datasets to identify any potential consistent identifiers
pre_columns = pre_assessment_data_cleaned.columns
post_columns = post_assessment_data_cleaned.columns

# Identifying common columns between the two datasets
common_columns = set(pre_columns).intersection(post_columns)
common_columns
# Out:
# {'DistributionChannel',
#  'Duration (in seconds)',
#  'EndDate',
#  'ExternalReference',
#  'Finished',
#  'IPAddress',
#  'LocationLatitude',
#  'LocationLongitude',
#  'Progress',
#  'Q30',
#  'Q31',
#  'Q36',
#  'Q37',
#  'Q52',
#  'RecipientEmail',
#  'RecipientFirstName',
#  'RecipientLastName',
#  'RecordedDate',
#  'ResponseId',
#  'SC0',
#  'StartDate',
#  'Status',
#  'UserLanguage'}

# %%
# Checking the uniqueness of the IPAddress column in both datasets to evaluate its suitability for merging
unique_ips_pre = pre_assessment_data_cleaned['IPAddress'].nunique()
unique_ips_post = post_assessment_data_cleaned['IPAddress'].nunique()

total_rows_pre = pre_assessment_data_cleaned.shape[0]
total_rows_post = post_assessment_data_cleaned.shape[0]

# Percentage of unique IP Addresses in each dataset
percentage_unique_ips_pre = (unique_ips_pre / total_rows_pre) * 100
percentage_unique_ips_post = (unique_ips_post / total_rows_post) * 100

(unique_ips_pre, total_rows_pre, percentage_unique_ips_pre, unique_ips_post, total_rows_post, percentage_unique_ips_post)
# Out:
# (67, 100, 67.0, 22, 29, 75.86206896551724)

# %%
# Performing a left join on IP address to see how many are common between pre and post datasets
merged_on_ip = pre_assessment_data_cleaned.merge(post_assessment_data_cleaned, on='IPAddress', how='left', suffixes=('_pre', '_post'))

# Counting the number of non-null entries in the post-assessment dataset after the merge
non_null_post_entries = merged_on_ip['SC0_post'].notnull().sum()

non_null_post_entries, merged_on_ip.shape[0]
# Out:
# (45, 116)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Selecting only the relevant columns for score improvement analysis
merged_scores = merged_on_ip[['SC0_pre', 'SC0_post']].dropna()

# Converting score columns to numeric for analysis
merged_scores['SC0_pre'] = pd.to_numeric(merged_scores['SC0_pre'], errors='coerce')
merged_scores['SC0_post'] = pd.to_numeric(merged_scores['SC0_post'], errors='coerce')

# Dropping NaN values in score columns (if any after conversion)
merged_scores = merged_scores.dropna()

# Calculating score improvement
merged_scores['score_improvement'] = merged_scores['SC0_post'] - merged_scores['SC0_pre']

# Plotting the Score Improvement
plt.figure(figsize=(10, 6))
sns.boxplot(data=merged_scores, x='score_improvement')
plt.title('Score Improvement from Pre to Post Assessment')
plt.xlabel('Score Improvement')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Filtering and preparing the data for analysis based on year in medical training
year_training_scores = pre_assessment_data_cleaned[[year_in_training_column, 'SC0']].dropna()

# Converting the score column to numeric
year_training_scores['SC0'] = pd.to_numeric(year_training_scores['SC0'], errors='coerce')

# Dropping NaN values in the score column
year_training_scores = year_training_scores.dropna()

unique_med_student_groups = [
    '2nd Year Medical Student',
    '3rd Year Medical Student',
    '1st Year Fellow',
    '2nd Year Fellow',
    '1st Year Resident',
    '2nd Year Resident',
    '4th Year Resident',
    '3rd Year Resident',
    'PA Student',
    'Other']

# Plotting Score Distribution by Year in Medical Training
plt.figure(figsize=(12, 8))
sns.boxplot(data=year_training_scores, x=year_in_training_column, y='SC0', order = unique_med_student_groups)
plt.title('Score Distribution by Year in Medical Training (Pre-Assessment)', fontsize=20)
plt.xlabel('Year in Medical Training', fontsize=15)
plt.ylabel('Scores', fontsize=15)
plt.xticks(rotation = 45, fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)
plt.show()

# %%
# Merging the year in medical training data from the pre-assessment with the merged scores data
merged_year_scores = merged_on_ip[['IPAddress', year_in_training_column, 'SC0_pre', 'SC0_post']].dropna()

# Converting score columns to numeric for analysis
merged_year_scores['SC0_pre'] = pd.to_numeric(merged_year_scores['SC0_pre'], errors='coerce')
merged_year_scores['SC0_post'] = pd.to_numeric(merged_year_scores['SC0_post'], errors='coerce')

# Dropping NaN values in score columns
merged_year_scores = merged_year_scores.dropna()

# Calculating score improvement
merged_year_scores['score_improvement'] = merged_year_scores['SC0_post'] - merged_year_scores['SC0_pre']

# Grouping by year in medical training and calculating average score improvement
average_improvement_by_year = merged_year_scores.groupby(year_in_training_column)['score_improvement'].mean().sort_values(ascending=False)

# Creating a DataFrame for plotting
plot_data = merged_year_scores.merge(average_improvement_by_year, on=year_in_training_column, suffixes=('', '_average'))
plot_data = plot_data.sort_values(by='score_improvement_average', ascending=False)

# Plotting Score Improvement by Year in Medical Training
plt.figure(figsize=(12, 8))
sns.boxplot(data=plot_data, x=year_in_training_column, y='score_improvement', order = unique_med_student_groups)
plt.title('Score Improvement by Year in Medical Training', fontsize=20)
plt.xlabel('Year in Medical Training', fontsize=15)
plt.ylabel('Score Improvement', fontsize=15)
plt.xticks(rotation = 45, fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)
plt.show()

# %%
# Preparing data for boxplot comparison between pre and post assessment scores
# Filtering and converting the score columns to numeric
pre_scores = pd.to_numeric(pre_assessment_data_cleaned[score_column], errors='coerce').dropna()
post_scores = pd.to_numeric(post_assessment_data_cleaned[score_column], errors='coerce').dropna()

import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

# Calculating means and standard errors
pre_mean = pre_scores.mean()
pre_se = pre_scores.sem()
post_mean = post_scores.mean()
post_se = post_scores.sem()

# Data for plotting
categories = ['Pre Assessment', 'Post Assessment']
means = [pre_mean, post_mean]
errors = [pre_se, post_se]

# Plotting
plt.figure(figsize=(10, 6))

# Error bars
plt.errorbar(categories[0], means[0], yerr=errors[0], fmt='o', label='Pre Assessment', ecolor='red', capsize=5)
plt.errorbar(categories[1], means[1], yerr=errors[1], fmt='o', label='Post Assessment', ecolor='blue', capsize=5)

# Adding labels and title
plt.title('Score Comparison: Pre vs Post Assessment')
plt.ylabel('Mean Scores')
plt.xticks(categories)
plt.legend()
plt.grid(True)

# Display the plot
plt.show()



# # Combining the scores into a single DataFrame for plotting
# combined_scores = pd.DataFrame({'Pre Assessment': pre_scores, 'Post Assessment': post_scores})

# # Plotting the Comparison Boxplot
# plt.figure(figsize=(10, 6))
# sns.boxplot(data=combined_scores)
# plt.title('Score Comparison: Pre vs Post Assessment')
# plt.ylabel('Scores')
# plt.grid(True)
# plt.show()

# %%
# Filtering out non-numeric rows in the 'SC0' column for both datasets
post_assessment_2022_filtered = post_assessment_2022[pd.to_numeric(post_assessment_2022['SC0'], errors='coerce').notnull()]
post_assessment_2023_filtered = post_assessment_data[pd.to_numeric(post_assessment_data['SC0'], errors='coerce').notnull()]

# Converting 'SC0' columns to numeric for analysis
post_assessment_2022_filtered['SC0'] = pd.to_numeric(post_assessment_2022_filtered['SC0'])
post_assessment_2023_filtered['SC0'] = pd.to_numeric(post_assessment_2023_filtered['SC0'])

# Combining the scores into a single DataFrame for plotting
combined_scores_comparison = pd.DataFrame({
    '2022 Post Assessment': post_assessment_2022_filtered['SC0'],
    '2023 Post Assessment': post_assessment_2023_filtered['SC0']
})

# Creating a violin plot for a different visualization of the score distributions
plt.figure(figsize=(10, 6))
sns.violinplot(data=combined_scores_comparison)
plt.title('Score Distribution Comparison: 2022 vs 2023 Post Assessment')
plt.ylabel('Scores')
plt.grid(True)
plt.show()
# Out:
# /var/folders/dt/736qq0rj57q0_yg7067yzwyh0000gn/T/ipykernel_1596/2519415934.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   post_assessment_2022_filtered['SC0'] = pd.to_numeric(post_assessment_2022_filtered['SC0'])
# /var/folders/dt/736qq0rj57q0_yg7067yzwyh0000gn/T/ipykernel_1596/2519415934.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   post_assessment_2023_filtered['SC0'] = pd.to_numeric(post_assessment_2023_filtered['SC0'])

# %%
import pandas as pd
import statsmodels.api as sm




# Ensuring 'SC0' is numeric and 'Q49_4' is categorical
post_assessment_data['SC0'] = pd.to_numeric(post_assessment_data['SC0'], errors='coerce')
post_assessment_data = post_assessment_data.dropna(subset=['SC0', 'Q49_4'])

# Creating a box plot with 'SC0' on the y-axis and the different responses in 'Q49_4' on the x-axis
plt.figure(figsize=(8, 4))
sns.barplot(x='Q49_4', y='SC0', data=post_assessment_data)
plt.title('Scores based on comfortability treating people with IDDs', fontsize=10)
plt.xlabel('I feel comfortable treating people with IDDs', fontsize=10)
plt.ylabel('Scores (SC0)', fontsize=10)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm




# Ensuring 'SC0' is numeric and 'Q49_4' is categorical
post_assessment_data['SC0'] = pd.to_numeric(post_assessment_data['SC0'], errors='coerce')
post_assessment_data = post_assessment_data.dropna(subset=['SC0', 'Q32_5'])

# Creating a box plot with 'SC0' on the y-axis and the different responses in 'Q49_4' on the x-axis
plt.figure(figsize=(12, 8))
sns.boxplot(x='Q32_5', y='SC0', data=post_assessment_data)
plt.title('Scores based would recommend', fontsize=15)
plt.xlabel('I would recommend this course to my colleagues', fontsize=15)
plt.ylabel('Scores (SC0)', fontsize=15)
plt.xticks(rotation=45, fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)
plt.show()

# %%
# Ensuring 'SC0' is numeric and 'Q49_4' is categorical
post_assessment_data['SC0'] = pd.to_numeric(post_assessment_data['SC0'], errors='coerce')
post_assessment_data = post_assessment_data.dropna(subset=['SC0', 'Q30'])

# Creating a box plot with 'SC0' on the y-axis and the different responses in 'Q49_4' on the x-axis
plt.figure(figsize=(12, 8))
sns.boxplot(x='Q30', y='SC0', data=post_assessment_data)
plt.title('Scores based on how satisfied', fontsize=15)
plt.xlabel('Overall, how satisfied were you with this training curriculum?', fontsize=15)
plt.ylabel('Scores (SC0)', fontsize=15)
plt.xticks(rotation=45, fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)
plt.show()

# %%
# Ensuring 'SC0' is numeric and 'Q49_4' is categorical
post_assessment_data['SC0'] = pd.to_numeric(post_assessment_data['SC0'], errors='coerce')
post_assessment_data = post_assessment_data.dropna(subset=['SC0', 'Q49_2'])

# Creating a box plot with 'SC0' on the y-axis and the different responses in 'Q49_4' on the x-axis
plt.figure(figsize=(12, 8))
sns.boxplot(x='Q49_2', y='SC0', data=post_assessment_data)
plt.title('Scores based if they think they have basic knowledge treating patients w IDD', fontsize=15)
plt.xlabel('I have basic knowledge in the treatment needs of patients with IDD.', fontsize=15)
plt.ylabel('Scores (SC0)', fontsize=15)
plt.xticks(rotation=45, fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)
plt.show()

# %%
# Ensuring 'SC0' is numeric and 'Q49_4' is categorical
post_assessment_data['SC0'] = pd.to_numeric(post_assessment_data['SC0'], errors='coerce')
post_assessment_data = post_assessment_data.dropna(subset=['SC0', 'Q32_4'])

# Creating a box plot with 'SC0' on the y-axis and the different responses in 'Q49_4' on the x-axis
plt.figure(figsize=(10, 6))
sns.barplot(x='Q32_4', y='SC0', data=post_assessment_data)
plt.title('Scores based if they plan to continue to pursue ways to increase their knowledge of the mental healthcare needs of people with IDD', fontsize=15)
plt.xlabel('I plan to continue to pursue ways to increase my knowledge of the mental healthcare needs of people with IDD', fontsize=15)
plt.ylabel('Scores (SC0)', fontsize=15)
plt.xticks(rotation=45, fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)
plt.show()

# %%
# Ensuring 'SC0' is numeric and 'Q49_4' is categorical
post_assessment_data['SC0'] = pd.to_numeric(post_assessment_data['SC0'], errors='coerce')
post_assessment_data = post_assessment_data.dropna(subset=['SC0', 'Q32_3'])

# Creating a box plot with 'SC0' on the y-axis and the different responses in 'Q49_4' on the x-axis
plt.figure(figsize=(12, 8))
sns.barplot(x='Q32_3', y='SC0', data=post_assessment_data)
plt.title('Scores based if format was conducive to learning', fontsize=15)
plt.xlabel('The format of this curriculum was conducive to my learning', fontsize=15)
plt.ylabel('Scores (SC0)', fontsize=15)
plt.xticks(rotation=45, fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)
plt.show()

# %%
post_assessment_data
# Out:
#                                             StartDate  \
# 0                                          Start Date
# 1   {"ImportId":"startDate","timeZone":"America/De...
# 2                                      3/30/2022 8:37
# 3                                       4/7/2022 9:57
# 4                                       4/7/2022 9:57
# 5                                       4/7/2022 9:57
# 6                                       4/7/2022 9:58
# 7                                     5/16/2022 21:53
# 8                                      8/18/2022 9:18
# 9                                      8/18/2022 9:19
# 10                                     8/18/2022 9:19
# 11                                     8/18/2022 9:18
# 12                                     8/18/2022 9:19
# 13                                    9/18/2022 16:22
# 14                                    9/18/2022 18:41
# 15                                     9/19/2022 4:00
# 16                                    9/21/2022 10:56
# 17                                    10/7/2022 14:45
# 18                                     10/8/2022 5:06
# 19                                    10/8/2022 10:48
# 20                                   10/10/2022 16:22
# 21                                   10/10/2022 19:18
# 22                                   10/11/2022 10:38
# 23                                   10/13/2022 14:50
# 24                                   10/15/2022 12:28
# 25                                   10/15/2022 16:55
# 26                                   10/15/2022 17:06
# 27                                   10/10/2022 16:24
# 28                                     12/2/2022 7:05
# 29                                     12/2/2022 7:06
# 30                                     2/3/2023 13:30
#
#                                               EndDate                 Status  \
# 0                                            End Date          Response Type
# 1   {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                      3/30/2022 8:43             IP Address
# 3                                      4/7/2022 10:05             IP Address
# 4                                      4/7/2022 10:07             IP Address
# 5                                      4/7/2022 10:08             IP Address
# 6                                      4/7/2022 10:09             IP Address
# 7                                     5/16/2022 22:06             IP Address
# 8                                      8/18/2022 9:23             IP Address
# 9                                      8/18/2022 9:24             IP Address
# 10                                     8/18/2022 9:25             IP Address
# 11                                     8/18/2022 9:29             IP Address
# 12                                     8/18/2022 9:26             IP Address
# 13                                    9/18/2022 17:22             IP Address
# 14                                    9/18/2022 18:51             IP Address
# 15                                     9/19/2022 4:10             IP Address
# 16                                    9/21/2022 11:06             IP Address
# 17                                    10/7/2022 15:03             IP Address
# 18                                     10/8/2022 5:35             IP Address
# 19                                    10/8/2022 11:51             IP Address
# 20                                   10/10/2022 16:27             IP Address
# 21                                   10/10/2022 19:36             IP Address
# 22                                   10/11/2022 11:21             IP Address
# 23                                   10/13/2022 15:36             IP Address
# 24                                   10/15/2022 12:35             IP Address
# 25                                   10/15/2022 17:04             IP Address
# 26                                   10/15/2022 17:07             IP Address
# 27                                   10/10/2022 16:28             IP Address
# 28                                     12/2/2022 7:12             IP Address
# 29                                     12/2/2022 7:16             IP Address
# 30                                     2/3/2023 13:52             IP Address
#
#                    IPAddress                 Progress  \
# 0                 IP Address                 Progress
# 1   {"ImportId":"ipAddress"}  {"ImportId":"progress"}
# 2            174.212.131.196                      100
# 3             216.66.108.218                      100
# 4            130.189.175.148                      100
# 5            130.189.175.200                      100
# 6            130.189.153.231                      100
# 7              73.68.200.152                      100
# 8             216.66.108.218                      100
# 9            130.189.175.148                      100
# 10           130.189.175.152                      100
# 11            216.66.108.218                      100
# 12           130.189.175.148                      100
# 13            73.149.158.196                      100
# 14            73.149.159.172                      100
# 15             76.24.228.186                      100
# 16             64.222.162.82                      100
# 17             73.219.254.20                      100
# 18              66.97.168.61                      100
# 19             98.11.121.232                      100
# 20             76.24.252.104                      100
# 21               73.89.92.74                      100
# 22             64.222.162.82                      100
# 23              75.69.94.255                      100
# 24              75.69.102.86                      100
# 25               52.124.6.68                      100
# 26               52.124.6.68                      100
# 27             76.24.252.104                       73
# 28             67.224.128.70                      100
# 29              172.56.35.68                      100
# 30             76.119.230.62                      100
#
#       Duration (in seconds)                 Finished  \
# 0     Duration (in seconds)                 Finished
# 1   {"ImportId":"duration"}  {"ImportId":"finished"}
# 2                       342                     TRUE
# 3                       513                     TRUE
# 4                       626                     TRUE
# 5                       657                     TRUE
# 6                       666                     TRUE
# 7                       757                     TRUE
# 8                       273                     TRUE
# 9                       297                     TRUE
# 10                      412                     TRUE
# 11                      647                     TRUE
# 12                      418                     TRUE
# 13                     3595                     TRUE
# 14                      557                     TRUE
# 15                      633                     TRUE
# 16                      628                     TRUE
# 17                     1105                     TRUE
# 18                     1738                     TRUE
# 19                     3751                     TRUE
# 20                      335                     TRUE
# 21                     1067                     TRUE
# 22                     2635                     TRUE
# 23                     2758                     TRUE
# 24                      414                     TRUE
# 25                      526                     TRUE
# 26                       56                     TRUE
# 27                      219                    FALSE
# 28                      420                     TRUE
# 29                      586                     TRUE
# 30                     1315                     TRUE
#
#                                          RecordedDate  \
# 0                                       Recorded Date
# 1   {"ImportId":"recordedDate","timeZone":"America...
# 2                                      3/30/2022 8:43
# 3                                      4/7/2022 10:05
# 4                                      4/7/2022 10:07
# 5                                      4/7/2022 10:08
# 6                                      4/7/2022 10:09
# 7                                     5/16/2022 22:06
# 8                                      8/18/2022 9:23
# 9                                      8/18/2022 9:24
# 10                                    8/18/2022 10:11
# 11                                    8/18/2022 10:17
# 12                                    8/18/2022 11:31
# 13                                    9/18/2022 17:22
# 14                                    9/18/2022 18:51
# 15                                     9/19/2022 4:10
# 16                                    9/21/2022 11:06
# 17                                    10/7/2022 15:03
# 18                                     10/8/2022 5:35
# 19                                    10/8/2022 11:51
# 20                                   10/10/2022 16:27
# 21                                   10/10/2022 19:36
# 22                                   10/11/2022 11:21
# 23                                   10/13/2022 15:36
# 24                                   10/15/2022 12:35
# 25                                   10/15/2022 17:04
# 26                                   10/15/2022 17:07
# 27                                   10/17/2022 16:28
# 28                                     12/2/2022 7:12
# 29                                     12/2/2022 7:16
# 30                                     2/3/2023 13:52
#
#                   ResponseId                 RecipientLastName  ...  \
# 0                Response ID               Recipient Last Name  ...
# 1   {"ImportId":"_recordId"}  {"ImportId":"recipientLastName"}  ...
# 2          R_31XbBuf7cpN9G8J                               NaN  ...
# 3          R_2D5lalLKtLsTWkZ                               NaN  ...
# 4          R_3D1hs06lyOhFtsk                               NaN  ...
# 5          R_32637n9t6RuswHP                               NaN  ...
# 6          R_3PLUU1EpPQfrJiy                               NaN  ...
# 7          R_21jIwrn4fEuch5D                               NaN  ...
# 8          R_24hK5CMUoA9UGkW                               NaN  ...
# 9          R_3PlncF0ASG7vtq9                               NaN  ...
# 10         R_D94rZzAEBQZip4B                               NaN  ...
# 11         R_2WxtAqigZqnb02r                               NaN  ...
# 12         R_3JkgAOjbN4hCQ5d                               NaN  ...
# 13         R_3MJQ8ZGVx0PKgyi                               NaN  ...
# 14         R_3GvNuB14sGtzhVN                               NaN  ...
# 15         R_2YIWgbGl2R61agR                               NaN  ...
# 16         R_1je16mpG2rA2yl7                               NaN  ...
# 17         R_1nUFD3xbVpFkCiT                               NaN  ...
# 18         R_2uvwBvggP7ji7q5                               NaN  ...
# 19         R_87E7hvBEezeo05b                               NaN  ...
# 20         R_1dHAuKq6O0S9gbg                               NaN  ...
# 21         R_3QRI263nOxRWaxR                               NaN  ...
# 22         R_264lnNCDBTZ7COR                               NaN  ...
# 23         R_2TNSJNpRsff14aH                               NaN  ...
# 24         R_3FQcttdO06ljRLi                               NaN  ...
# 25         R_NWrLWBBTBapYMvf                               NaN  ...
# 26         R_12nBiuhGIAbsY9I                               NaN  ...
# 27         R_2fIemNmCi81slRQ                               NaN  ...
# 28         R_bwoklJIODdnEhNf                               NaN  ...
# 29         R_0xjvsZoOObO26SB                               NaN  ...
# 30         R_BxhajAU6vqcC5i1                               NaN  ...
#
#                                                 Q32_5  \
# 0   Please rate your level of agreement with the f...
# 1                              {"ImportId":"QID72_5"}
# 2                                            Disagree
# 3                                      Strongly Agree
# 4                                      Strongly Agree
# 5                                      Strongly Agree
# 6                                      Strongly Agree
# 7                                               Agree
# 8                                      Strongly Agree
# 9                                            Disagree
# 10                                           Disagree
# 11                                     Strongly Agree
# 12                                           Disagree
# 13                                     Strongly Agree
# 14                                     Strongly Agree
# 15                                              Agree
# 16                                           Disagree
# 17                                              Agree
# 18                                              Agree
# 19                                              Agree
# 20                                              Agree
# 21                                              Agree
# 22                                              Agree
# 23                                              Agree
# 24                                     Strongly Agree
# 25                                              Agree
# 26                                              Agree
# 27                                                NaN
# 28                                     Strongly Agree
# 29                                     Strongly Agree
# 30                                     Strongly Agree
#
#                                                 Q34_1  \
# 0   Please rate the degree to which you agree that...
# 1                              {"ImportId":"QID74_1"}
# 2                                      Strongly Agree
# 3                                      Strongly Agree
# 4                                      Strongly Agree
# 5                                      Strongly Agree
# 6                                               Agree
# 7                                               Agree
# 8                                      Strongly Agree
# 9                                      Strongly Agree
# 10                                              Agree
# 11                                     Strongly Agree
# 12                                              Agree
# 13                                     Strongly Agree
# 14                                     Strongly Agree
# 15                                     Strongly Agree
# 16                                              Agree
# 17                                     Strongly Agree
# 18                                              Agree
# 19                                     Strongly Agree
# 20                                              Agree
# 21                                              Agree
# 22                                              Agree
# 23                                              Agree
# 24                                     Strongly Agree
# 25                                              Agree
# 26                                              Agree
# 27                                                NaN
# 28                                     Strongly Agree
# 29                                     Strongly Agree
# 30                                              Agree
#
#                                                 Q34_2  \
# 0   Please rate the degree to which you agree that...
# 1                              {"ImportId":"QID74_2"}
# 2                                               Agree
# 3                                      Strongly Agree
# 4                                      Strongly Agree
# 5                                      Strongly Agree
# 6                                               Agree
# 7                                               Agree
# 8                                      Strongly Agree
# 9                                               Agree
# 10                                              Agree
# 11                                     Strongly Agree
# 12                                              Agree
# 13                                     Strongly Agree
# 14                                     Strongly Agree
# 15                                     Strongly Agree
# 16                                              Agree
# 17                                              Agree
# 18                                              Agree
# 19                                     Strongly Agree
# 20                                              Agree
# 21                                              Agree
# 22                                              Agree
# 23                                              Agree
# 24                                     Strongly Agree
# 25                                              Agree
# 26                                              Agree
# 27                                                NaN
# 28                                     Strongly Agree
# 29                                     Strongly Agree
# 30                                              Agree
#
#                                                 Q34_3  \
# 0   Please rate the degree to which you agree that...
# 1                              {"ImportId":"QID74_3"}
# 2                                            Disagree
# 3                                      Strongly Agree
# 4                                      Strongly Agree
# 5                                      Strongly Agree
# 6                                               Agree
# 7                                               Agree
# 8                                      Strongly Agree
# 9                                               Agree
# 10                                              Agree
# 11                                     Strongly Agree
# 12                                              Agree
# 13                                     Strongly Agree
# 14                                     Strongly Agree
# 15                                     Strongly Agree
# 16                                              Agree
# 17                                              Agree
# 18                                              Agree
# 19                                     Strongly Agree
# 20                                              Agree
# 21                                              Agree
# 22                                              Agree
# 23                                              Agree
# 24                                     Strongly Agree
# 25                                              Agree
# 26                                              Agree
# 27                                                NaN
# 28                                     Strongly Agree
# 29                                     Strongly Agree
# 30                                              Agree
#
#                                                 Q34_4  \
# 0   Please rate the degree to which you agree that...
# 1                              {"ImportId":"QID74_4"}
# 2                                   Strongly Disagree
# 3                                      Strongly Agree
# 4                                      Strongly Agree
# 5                                      Strongly Agree
# 6                                               Agree
# 7                                               Agree
# 8                                      Strongly Agree
# 9                                               Agree
# 10                                              Agree
# 11                                     Strongly Agree
# 12                                              Agree
# 13                                     Strongly Agree
# 14                                     Strongly Agree
# 15                                     Strongly Agree
# 16                                              Agree
# 17                                              Agree
# 18                                              Agree
# 19                                     Strongly Agree
# 20                                              Agree
# 21                                              Agree
# 22                                              Agree
# 23                                              Agree
# 24                                     Strongly Agree
# 25                                              Agree
# 26                                              Agree
# 27                                                NaN
# 28                                     Strongly Agree
# 29                                     Strongly Agree
# 30                                              Agree
#
#                                                   Q35  \
# 0   What did you find particularly helpful about t...
# 1                           {"ImportId":"QID75_TEXT"}
# 2                                          everything
# 3   The patient experiences, providers clearly out...
# 4   Felt it appropriately combined expert knowledg...
# 5   Focusing on patient's perspective rather than ...
# 6                                 Patient experiences
# 7   there are may things one has to take into acco...
# 8   Presenters who were more interactive and not j...
# 9   Some of the separation of common manifestation...
# 10                                     Good overview
# 11  Experiences of people with IDD and their families
# 12        Specific pearls from experienced providers
# 13  I thought the personal experiences helped me u...
# 14  I really enjoyed this course. I particularly l...
# 15  I really liked getting basic information/treat...
# 16                   I found the information helpful.
# 17                                            Videos!
# 18  The course outline was great. I liked how the ...
# 19  I liked the insgiht from IDD indiviudals. The ...
# 20  the insight and education into what positive m...
# 21  I enjoyed that the videos were broken up so th...
# 22  The definitions and explanations of behaviors ...
# 23  I enjoyed hearing from self advocates and runn...
# 24  Learning more about IDD patients and how as pr...
# 25  Increased my knowledge of cultural competent c...
# 26                                            culture
# 27                                                NaN
# 28                                        Everything
# 29  Discussion of pharmacotherapy, point of view a...
# 30  The advanced section was most helpful for me a...
#
#                                                   Q36  \
# 0   What are your recommendations to improve this ...
# 1                           {"ImportId":"QID76_TEXT"}
# 2                                                 NaN
# 3      Shorter videos, less videos, more interaction
# 4   Could be helpful to have more interactive comp...
# 5   Adding some interactive components during vide...
# 6   Unsure as I do not know what level of educatio...
# 7                       The lay out could be simpler.
# 8   More family advocates who aren't reading prepa...
# 9                                                 N/a
# 10                                            Unsure
# 11  It would be helpful to have more examples/case...
# 12                         Focus on specific audience
# 13  I thought the course was well-organized and in...
# 14  It would be better to do a feedback survey dir...
# 15  Either shorten the videos or make it more inte...
# 16  I think there should be another way to assess ...
# 17  Difficult to address the underlying biases we ...
# 18  Providing topic notes to download would be hel...
# 19  Some speakers seeemed to just be reading off a...
# 20       leave out repeat questions in post surverys.
# 21  Cut down the length of time per video. 6 hrs t...
# 22  The course was a little confusing to follow wi...
# 23  I would try to apply the lessons more with eit...
# 24  No recommendations at this time, this was a ve...
# 25                            None. It was phemomenal
# 26                                            culture
# 27                                                NaN
# 28                                          Its great
# 29                                               None
# 30  It would be nice to have the PP available to t...
#
#                                                   Q37  \
# 0   Are you interested in receiving information ab...
# 1                                {"ImportId":"QID77"}
# 2                                                 Yes
# 3                                                 Yes
# 4                                                  No
# 5                                                  No
# 6                                                  No
# 7                                                  No
# 8                                                 Yes
# 9                                                  No
# 10                                                 No
# 11                                                 No
# 12                                                 No
# 13                                                Yes
# 14                                                Yes
# 15                                                 No
# 16                                                 No
# 17                                                 No
# 18                                                 No
# 19                                                 No
# 20                                                 No
# 21                                                 No
# 22                                                 No
# 23                                                 No
# 24                                                 No
# 25                                                 No
# 26                                                 No
# 27                                                NaN
# 28                                                Yes
# 29                                                Yes
# 30                                                 No
#
#                                                 Q38.1  \
# 0   If yes, please provide your first name, last n...
# 1                           {"ImportId":"QID78_TEXT"}
# 2                                                 NaN
# 3                    Kat Han, katherine.han@gmail.com
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Mitchell Cunningham\nMitchell.a.cunningham@gma...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13           Savanna Woodford \n\nwoodford.66@osu.edu
# 14           Lilly Friedman, LillyRFriedman@gmail.com
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28           Gerardo Collazo\ngerardo.collazo@upr.edu
# 29      Fransheska Rivera\nfransheska.rivera1@upr.edu
# 30                                                NaN
#
#                                   SC0
# 0                               Score
# 1   {"ImportId":"SC_1YuDNHwVBISrDAa"}
# 2                                   3
# 3                                  23
# 4                                  22
# 5                                  18
# 6                                  22
# 7                                  20
# 8                                  10
# 9                                  16
# 10                                 19
# 11                                 20
# 12                                 22
# 13                                 24
# 14                                 20
# 15                                 17
# 16                                 16
# 17                                 19
# 18                                 20
# 19                                 23
# 20                                 14
# 21                                 18
# 22                                 15
# 23                                 15
# 24                                 13
# 25                                 10
# 26                                  2
# 27                                 13
# 28                                 18
# 29                                 22
# 30                                 23
#
# [31 rows x 51 columns]

# %%
question_columns = ['Q42', 'Q60', 'Q58', 'Q62', 'Q50', 'Q52', 'Q64', 'Q66']

selected_data = post_assessment_data[question_columns]

selected_data.head()
# Out:
#                                                  Q42  \
# 0  Which of the following statements are true abo...
# 1                               {"ImportId":"QID82"}
# 2                                                NaN
# 3  In order to receive IDD services, the person m...
# 4  In order to receive IDD services, the person m...
#
#                                                  Q60  \
# 0  Which of the following statements are true whe...
# 1                               {"ImportId":"QID91"}
# 2                                                NaN
# 3  Medical/biological issues should be ruled out ...
# 4  Medical/biological issues should be ruled out ...
#
#                                                  Q58  \
# 0  Which of the following is not a common present...
# 1                               {"ImportId":"QID57"}
# 2                       Talking to inanimate objects
# 3                       Talking to inanimate objects
# 4                       Talking to inanimate objects
#
#                                                  Q62  \
# 0  Signs of psychosis in people with intellectual...
# 1                               {"ImportId":"QID59"}
# 2  Auditory hallucinations that are intrusive and...
# 3  Auditory hallucinations that are intrusive and...
# 4  Auditory hallucinations that are intrusive and...
#
#                                                  Q50  \
# 0  Which of the following are best practices in c...
# 1                               {"ImportId":"QID86"}
# 2                                                NaN
# 3  Ask your patient exploratory questions,Ask que...
# 4  Ask your patient exploratory questions,Ask que...
#
#                                                  Q52  \
# 0  If a patient with IDD-MH is acting out in your...
# 1                               {"ImportId":"QID87"}
# 2                                                NaN
# 3  Get a copy of their behavior plan for the next...
# 4  Get a copy of their behavior plan for the next...
#
#                                                  Q64  \
# 0  Which of these is not a treatment approach tha...
# 1                               {"ImportId":"QID60"}
# 2  Extensive, long-term behavior modification tre...
# 3  Extensive, long-term behavior modification tre...
# 4  Extensive, long-term behavior modification tre...
#
#                                                  Q66
# 0  Which of these medications are among those tha...
# 1                               {"ImportId":"QID61"}
# 2                                        cariprazine
# 3        lithium,divalproex,aripiprazole,risperidone
# 4  lithium,quetiapine,divalproex,aripiprazole,ris...

# %%
rename_dict = {
    'Q42': 'Q31',
    'Q60': 'Q36',
    'Q58': 'Q37',
    'Q62': 'Q39',
    'Q50': 'Q12',
    'Q52': 'Q13',
    'Q64': 'Q22',
    'Q66': 'Q23'
}

renamed_post_questions = selected_data.rename(columns=rename_dict)

renamed_post_questions.head()
# Out:
#                                                  Q31  \
# 0  Which of the following statements are true abo...
# 1                               {"ImportId":"QID82"}
# 2                                                NaN
# 3  In order to receive IDD services, the person m...
# 4  In order to receive IDD services, the person m...
#
#                                                  Q36  \
# 0  Which of the following statements are true whe...
# 1                               {"ImportId":"QID91"}
# 2                                                NaN
# 3  Medical/biological issues should be ruled out ...
# 4  Medical/biological issues should be ruled out ...
#
#                                                  Q37  \
# 0  Which of the following is not a common present...
# 1                               {"ImportId":"QID57"}
# 2                       Talking to inanimate objects
# 3                       Talking to inanimate objects
# 4                       Talking to inanimate objects
#
#                                                  Q39  \
# 0  Signs of psychosis in people with intellectual...
# 1                               {"ImportId":"QID59"}
# 2  Auditory hallucinations that are intrusive and...
# 3  Auditory hallucinations that are intrusive and...
# 4  Auditory hallucinations that are intrusive and...
#
#                                                  Q12  \
# 0  Which of the following are best practices in c...
# 1                               {"ImportId":"QID86"}
# 2                                                NaN
# 3  Ask your patient exploratory questions,Ask que...
# 4  Ask your patient exploratory questions,Ask que...
#
#                                                  Q13  \
# 0  If a patient with IDD-MH is acting out in your...
# 1                               {"ImportId":"QID87"}
# 2                                                NaN
# 3  Get a copy of their behavior plan for the next...
# 4  Get a copy of their behavior plan for the next...
#
#                                                  Q22  \
# 0  Which of these is not a treatment approach tha...
# 1                               {"ImportId":"QID60"}
# 2  Extensive, long-term behavior modification tre...
# 3  Extensive, long-term behavior modification tre...
# 4  Extensive, long-term behavior modification tre...
#
#                                                  Q23
# 0  Which of these medications are among those tha...
# 1                               {"ImportId":"QID61"}
# 2                                        cariprazine
# 3        lithium,divalproex,aripiprazole,risperidone
# 4  lithium,quetiapine,divalproex,aripiprazole,ris...
